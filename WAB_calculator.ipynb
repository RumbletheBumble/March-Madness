# %% [markdown]
# <a href="https://colab.research.google.com/github/RumbletheBumble/March-Madness/blob/main/WAB_calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# List of team names (with seed numbers)
teams_with_seeds = [
    "Connecticut 1", "Houston 1", "Purdue 1", "Auburn 4", "Tennessee 2", "Arizona 2", "Duke 4",
    "Iowa St. 2", "North Carolina 1", "Illinois 3", "Creighton 3", "Gonzaga 5", "Marquette 2",
    "Alabama 4", "Baylor 3", "Michigan St. 9", "Wisconsin 5", "BYU 6", "Clemson 6", "Saint Mary's 5",
    "St. John's", "San Diego St. 5", "Kentucky 3", "Colorado 10", "Texas 7", "Florida 7", "Kansas 4",
    "Wake Forest", "New Mexico 11", "Nebraska 8", "Texas Tech 6", "Dayton 7", "Pittsburgh",
    "Mississippi St. 8", "Texas A&M 9", "Colorado St. 10", "Villanova", "Indiana St.", "Cincinnati",
    "Nevada 10", "Northwestern 9", "Washington St. 7", "TCU 9", "Boise St. 10", "N.C. State 11",
    "Oklahoma", "Florida Atlantic 8", "Utah", "Ohio St.", "Seton Hall", "Utah St. 8", "Grand Canyon 12",
    "Drake 10", "South Carolina 6", "Oregon 11", "Xavier", "Iowa", "Virginia Tech", "Providence",
    "Washington", "Butler", "Maryland", "James Madison 12", "Bradley", "San Francisco", "UCF",
    "McNeese St. 12", "Virginia 10", "Princeton", "Kansas St.", "Boston College", "SMU", "UNLV",
    "North Texas", "VCU", "Memphis", "Penn St.", "Minnesota", "Florida St.", "Syracuse", "Samford 13",
    "UC Irvine", "Appalachian St.", "Georgia", "USC", "Mississippi", "South Florida", "Duquesne 11",
    "Richmond", "Yale 13", "Indiana", "Massachusetts", "Loyola Chicago", "Louisiana Tech", "LSU",
    "Miami FL", "George Mason", "UCLA", "Saint Joseph's", "Rutgers", "Charleston 13", "St. Bonaventure",
    "Cornell", "Vermont 13", "Stanford", "UAB 12", "Seattle", "Arkansas", "Santa Clara",
    "Western Carolina", "Northern Iowa", "UT Arlington", "Hofstra", "High Point", "Belmont",
    "Morehead St. 14", "Oklahoma St.", "Notre Dame", "UNC Wilmington", "Charlotte", "California",
    "Akron 14", "Georgia Tech", "Southern Illinois", "Davidson", "Drexel", "Arizona St.", "Michigan",
    "Tarleton St.", "UC San Diego", "Oakland 14", "Troy", "Arkansas St.", "Youngstown St.",
    "Western Kentucky 15", "Tulane", "Liberty", "South Dakota St. 15", "Toledo", "Chattanooga", "Furman",
    "Sam Houston St.", "Ohio", "West Virginia", "Missouri", "Towson", "UNC Greensboro", "St. Thomas",
    "Missouri St.", "Colgate 14", "Louisiana", "Eastern Washington", "UMass Lowell", "Wichita St.",
    "Oregon St.", "Weber St.", "Purdue Fort Wayne", "Wright St.", "Wyoming", "Murray St.", "Longwood 16",
    "Utah Valley", "Montana", "UNC Asheville", "Long Beach St. 15", "Lipscomb", "Hawaii", "Stony Brook",
    "Delaware", "Stephen F. Austin", "Kent St.", "Quinnipiac", "Bryant", "East Tennessee St.",
    "Fairfield", "Winthrop", "UC Davis", "UTEP", "Illinois St.", "Texas St.", "Temple",
    "Texas A&M Corpus Chris", "Vanderbilt", "Tulsa", "Louisville", "Northern Kentucky", "Loyola Marymount",
    "Fordham", "East Carolina", "Cal Baptist", "Brown", "Georgetown", "Wofford", "Little Rock", "La Salle",
    "Illinois Chicago", "Cleveland St.", "Monmouth", "Saint Louis", "Jacksonville St.", "Saint Peter's 15",
    "Northern Colorado", "George Washington", "Gardner Webb", "UC Santa Barbara", "Rhode Island",
    "Abilene Christian", "Evansville", "Mercer", "Lamar", "Eastern Kentucky", "Merrimack", "Penn",
    "UMKC", "Marist", "Tennessee Martin", "UC Riverside", "Georgia St.", "Norfolk St.", "Stetson 16",
    "South Alabama", "Milwaukee", "Montana St. 16", "Pepperdine", "Rider", "Iona", "Radford", "Harvard",
    "Rice", "Green Bay", "Maine", "Columbia", "Cal St. Northridge", "Nicholls St.", "Cal St. Fullerton",
    "North Dakota", "Fresno St.", "Marshall", "Bowling Green", "North Florida", "Florida Gulf Coast",
    "Southern Utah", "Southern Miss", "Albany", "Austin Peay", "New Hampshire", "Cal St. Bakersfield",
    "San Jose St.", "Mount St. Mary's", "Northeastern", "Portland St.", "North Alabama",
    "North Carolina Central", "UTSA", "The Citadel", "San Diego", "Miami OH", "Idaho St.",
    "Grambling St. 16", "Nebraska Omaha", "Southern", "Central Connecticut", "Lehigh", "Air Force",
    "Kennesaw St.", "Ball St.", "Texas Southern", "Denver", "Queens", "Western Illinois", "Presbyterian",
    "Niagara", "Jacksonville", "UMBC", "Howard 16", "Bucknell", "Central Michigan", "Canisius",
    "North Dakota St.", "Georgia Southern", "Utah Tech", "Middle Tennessee", "Oral Roberts",
    "Binghamton", "FIU", "SIU Edwardsville", "Old Dominion", "USC Upstate", "Delaware St.",
    "New Mexico St.", "Tennessee St.", "Wagner 16", "Sacred Heart", "Alcorn St.", "Chicago St.",
    "American", "Boston University", "Louisiana Monroe", "Portland", "Valparaiso",
    "South Carolina St.", "Le Moyne", "Bethune Cookman", "DePaul", "Western Michigan",
    "Southeastern Louisiana", "Robert Morris", "Northern Illinois", "Jackson St.", "Alabama St.",
    "Campbell", "Northern Arizona", "Coastal Carolina", "Sacramento St.", "Charleston Southern",
    "Bellarmine", "Elon", "Lafayette", "William & Mary", "Eastern Illinois", "Idaho", "South Dakota",
    "Navy", "Alabama A&M", "Northwestern St.", "Eastern Michigan", "Fairleigh Dickinson",
    "Southern Indiana", "UT Rio Grande Valley", "Prairie View A&M", "Arkansas Pine Bluff",
    "Tennessee Tech", "Texas A&M Commerce", "Morgan St.", "NJIT", "Dartmouth", "Manhattan",
    "Florida A&M", "Cal Poly", "Central Arkansas", "Hampton", "New Orleans", "LIU", "Army",
    "Incarnate Word", "North Carolina A&T", "Maryland Eastern Shore", "Buffalo", "Holy Cross",
    "Loyola MD", "Detroit Mercy", "Southeast Missouri St.", "VMI", "Saint Francis",
    "Houston Christian", "Lindenwood", "Siena", "Pacific", "Stonehill", "IUPUI", "Coppin St.",
    "Mississippi Valley St."
]

# Corresponding values
numbers = [
    0.1419996954, 0.1853061642, 0.2244805903, 0.2527272350, 0.2647294098,
    0.2833748609, 0.2921914899, 0.2546403474, 0.2875187129, 0.3522767676,
    0.3383406786, 0.3693647428, 0.3540747878, 0.3887135138, 0.3992573688,
    0.3954457608, 0.4319642952, 0.4369046638, 0.4406945330, 0.4245376151,
    0.4460095153, 0.4222704104, 0.4610272210, 0.4510509190, 0.4508861128,
    0.4795089020, 0.4617016374, 0.4782881002, 0.4679397177, 0.4826387526,
    0.4921591054, 0.4932599060, 0.4913381270, 0.4805068084, 0.5000000000,
    0.4869857807, 0.4820346239, 0.5157233068, 0.4922705715, 0.5060490532,
    0.5092751857, 0.5020098872, 0.5151092195, 0.5104620364, 0.5162313931,
    0.5206037093, 0.5330643265, 0.5298913534, 0.5368854781, 0.5349319729,
    0.9033915590, 0.9030283964, 0.9026402896, 0.9044840727, 0.9031586403,
    0.9085896177, 0.9063517542, 0.9072211717, 0.9043972788, 0.9054836667,
    0.9082776406, 0.9106766740, 0.9070954557, 0.9091983469, 0.9127984577,
    0.9104478895, 0.9103328299, 0.9123497341, 0.9115264095, 0.9104735758,
    0.9150598137, 0.9165693627, 0.9158326937, 0.9128092978, 0.9130519730,
    0.9173615913, 0.9184799127, 0.9152573582, 0.9171640329, 0.9183854109,
    0.9225310599, 0.9252495228, 0.9252495228, 0.9279544711, 0.9249960630,
    0.9259454935, 0.9275600648, 0.9245689573, 0.9219289571, 0.9256870129,
    0.9255526351, 0.9288054965, 0.9288625991, 0.9267525055, 0.9293305505,
    0.9306824660, 0.9312093424, 0.9326194516, 0.9302663440, 0.9335396232,
    0.9354746489, 0.9335111680, 0.9332621887, 0.9348090789, 0.9423615107,
    0.9379191539, 0.9394461562, 0.9411974783, 0.9430017582, 0.9447496510,
    0.9421528330, 0.9421721861, 0.9483450312, 0.9442552756, 0.9480744226,
    0.9475641642, 0.9445954414, 0.9498193867, 0.9519064330, 0.9513542795,
    0.9534661613, 0.9531813234, 0.9567017842, 0.9573151405, 0.9596497149,
    0.9559052184, 0.9597223270, 0.9606801472, 0.9590682787, 0.9596907649,
    0.9625784240, 0.9623637132, 0.9644256200, 0.9643411270, 0.9630946949,
    0.9649474362, 0.9639693222, 0.9679360884, 0.9695549775, 0.9664334134,
    0.9678096182, 0.9719741470, 0.9689325223, 0.9660898805, 0.9715692169,
    0.9704132162, 0.9751223319, 0.9774078051, 0.9754804826, 0.9746241402,
    0.9771813761, 0.9785116437, 0.9760565374, 0.9778541543, 0.9822023815,
    0.9850141721, 0.9904287384
]



# Clean seed numbers using regex
cleaned_teams = [re.sub(r'\s+\d+$', '', team) for team in teams_with_seeds]

# Zip into dictionary
team_avg_win = dict(zip(cleaned_teams, numbers))

# %%
schedule = [
    ("Gonzaga", "L"),
    ("Loyola Marymount", "W"),
    ("Colgate", "W"),
    ("Weber St.", "L"),
    ("Gardner Webb", "W"),
    ("Rhode Island", "L"),
    ("Stony Brook", "W"),
    ("Vermont", "L"),
    ("Fairfield", "L"),
    ("Quinnipiac", "W"),
    ("Kansas", "L"),
    ("Santa Clara", "W"),
    ("Howard", "W"),
    ("Brown", "W"),
    ("Columbia", "W"),
    ("Dartmouth", "W"),
    ("Harvard", "W"),
    ("Princeton", "W"),
    ("Penn", "W"),
    ("Cornell", "W"),
    ("Penn", "W"),
    ("Princeton", "L"),
    ("Cornell", "L"),
    ("Columbia", "W"),
    ("Dartmouth", "W"),
    ("Harvard", "W"),
    ("Brown", "L"),
    ("Cornell", "W"),
    ("Brown", "W")
]


wab = []

for i, u in schedule:
  if u == 'W':
    wab.append(1-team_avg_win[i])
  else:
    wab.append(team_avg_win[i] * -1)

print(wab)
print(sum(wab))
# Out:
# [-0.3693647428, 0.14519898880000004, 0.19487454719999997, -0.8145103164, 0.12913126009999998, -0.8713277459, 0.16533021699999995, -0.7156637803, -0.8395163752, 0.16266055420000003, -0.4617016374, 0.26313828949999996, 0.08952642420000001, 0.1430354533, 0.11339645620000005, 0.037421575999999956, 0.11588220459999998, 0.37382000579999997, 0.1276126768, 0.28764829189999996, 0.1276126768, -0.6261799942, -0.7123517081, 0.11339645620000005, 0.037421575999999956, 0.11588220459999998, -0.8569645467, 0.28764829189999996, 0.1430354533]
# -3.0939072426000003
